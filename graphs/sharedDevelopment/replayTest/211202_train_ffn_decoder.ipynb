# %%
# Imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import yaml
from brand import initializeRedisFromYAML
from sklearn import metrics
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras import layers

from utils import get_lagged_features, load_stream

# %%
# Options
BATCH_SIZE = 2048
LR = 1e-1
NORMALIZE = True  # whether to normalize the data

# Neural Network Hyperparameters
HIDDEN_DIM = 96
REG = 1e-4  # L2 regularization weight

# %%
# Load Data
# connect to Redis
r = initializeRedisFromYAML('replayTest.yaml')

# load stream information
with open('stream_spec.yaml', 'r') as f:
    stream_spec = yaml.safe_load(f)

# load taskInput stream
task_input = load_stream(r, 'taskInput', stream_spec=stream_spec)
task_input = task_input.set_index('timestamps')

# load thresholdCrossings stream
threshold_crossings = load_stream(r,
                                  'thresholdCrossings',
                                  stream_spec=stream_spec)
# separate channels into their own columns
tc_timestamps = threshold_crossings['timestamps'].values
crossings = np.stack(threshold_crossings['crossings'])
n_chans = crossings.shape[1]

# correct the offset between thresholdCrossings and taskInput
offsets = list(range(-15, 16))
idx = np.argmax([
    np.intersect1d(task_input.index, tc_timestamps + i).shape[0]
    for i in offsets
])
offset = offsets[idx]

channel_labels = [f'ch{i :03d}' for i in range(n_chans)]
tc_df = pd.DataFrame(crossings,
                     index=tc_timestamps + offset,
                     columns=channel_labels)

# combine the taskInput and thresholdCrossing data
joined_df = task_input.join(tc_df, how='inner')
# convert index from samples to milliseconds
joined_df.index = pd.to_timedelta(joined_df.index / 30, unit='ms')

# split the behavioral data into columns
samples = np.stack(joined_df['samples'])
joined_df['touch'] = samples[:, 0]
joined_df['x'] = samples[:, 1]
joined_df['y'] = samples[:, 2]
# Out:
# connecting to Redis using: replayTest.yaml
# Redis IP: 127.0.0.1, Redis port: 6379
# Initialized Redis

# %%
# Pre-Processing
# resample the data
bin_size_ms = 5  # ms
binned_data = joined_df.resample(f'{bin_size_ms :d}ms').mean().dropna(axis=0)

# define the input X and output y
X = binned_data[channel_labels].values
y = binned_data[['x', 'y']].values

# get features
X = get_lagged_features(X, n_history=15)

# train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

if NORMALIZE:
    # scale the output
    output_scaler = StandardScaler()
    y_train = output_scaler.fit_transform(y_train)
    y_test = output_scaler.transform(y_test)

# %%
# Train a Linear Model
linear_model = Ridge(alpha=1.0)
linear_model.fit(X_train, y_train)

print(f'Train R^2: {linear_model.score(X_train, y_train)}')
print(f'Test R^2: {linear_model.score(X_test, y_test)}')

output = linear_model.predict(X)
if NORMALIZE:
    output = output_scaler.inverse_transform(output)
binned_data['x_pred_lm'] = output[:, 0]
binned_data['y_pred_lm'] = output[:, 1]
# Out:
# Train R^2: 0.73481595074205
# Test R^2: 0.7288478280725632

# %%
metrics.r2_score(binned_data[['x']], binned_data[['x_pred_lm']])
# Out:
# 0.4673417515895416

# %%
# Train a Neural Network
n_features = X_train.shape[1]
n_targets = y_train.shape[1]

# define the model
nn_model = keras.Sequential()
nn_model.add(layers.Input(shape=(n_features, )))
nn_model.add(
    layers.Dense(HIDDEN_DIM,
                 activation='relu',
                 kernel_regularizer=keras.regularizers.l2(REG)))
nn_model.add(
    layers.Dense(HIDDEN_DIM,
                 activation='relu',
                 kernel_regularizer=keras.regularizers.l2(REG)))
nn_model.add(
    layers.Dense(HIDDEN_DIM,
                 activation='relu',
                 kernel_regularizer=keras.regularizers.l2(REG)))
nn_model.add(
    layers.Dense(n_targets,
                 activation=None,
                 kernel_regularizer=keras.regularizers.l2(REG)))

# initialize the model graph
nn_model(np.random.rand(BATCH_SIZE, n_features))  # init

# compile the model
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=LR, decay_steps=10000, decay_rate=0.96)
optimizer = keras.optimizers.Adam(learning_rate=lr_schedule)
nn_model.compile(optimizer=optimizer, loss=keras.losses.MeanSquaredError())

callbacks = [
    # Stop training when `val_loss` is no longer improving
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        min_delta=1e-5,  # minimum improvement
        patience=10,  # epochs
        verbose=1,
        restore_best_weights=True,
    )
]

nn_model.fit(X_train,
             y_train,
             validation_data=(X_test, y_test),
             batch_size=BATCH_SIZE,
             epochs=1000,
             callbacks=callbacks)

output = nn_model(X).numpy()
if NORMALIZE:
    output = output_scaler.inverse_transform(output)
binned_data['x_pred_nn'] = output[:, 0]
binned_data['y_pred_nn'] = output[:, 1]
# Out:
# Epoch 1/1000
# 53/53 [==============================] - 1s 12ms/step - loss: 105.2230 - val_loss: 3.2232
# Epoch 2/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 3.1054 - val_loss: 2.9621
# Epoch 3/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 2.9109 - val_loss: 2.7986
# Epoch 4/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 2.8171 - val_loss: 2.6895
# Epoch 5/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 2.6480 - val_loss: 2.6840
# Epoch 6/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 2.5578 - val_loss: 2.4660
# Epoch 7/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 2.4717 - val_loss: 2.4116
# Epoch 8/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 2.3517 - val_loss: 2.2916
# Epoch 9/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 2.2692 - val_loss: 2.2055
# Epoch 10/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 2.1994 - val_loss: 2.1500
# Epoch 11/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 2.1289 - val_loss: 2.0966
# Epoch 12/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 2.0639 - val_loss: 2.0071
# Epoch 13/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.9934 - val_loss: 1.9663
# Epoch 14/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.9393 - val_loss: 1.8923
# Epoch 15/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.8839 - val_loss: 1.8797
# Epoch 16/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.8275 - val_loss: 1.7964
# Epoch 17/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.7744 - val_loss: 1.7324
# Epoch 18/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.7185 - val_loss: 1.6752
# Epoch 19/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.6919 - val_loss: 1.6352
# Epoch 20/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.6286 - val_loss: 1.5902
# Epoch 21/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.5800 - val_loss: 1.5381
# Epoch 22/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.5363 - val_loss: 1.5009
# Epoch 23/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.5093 - val_loss: 1.4676
# Epoch 24/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.4538 - val_loss: 1.4209
# Epoch 25/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.4241 - val_loss: 1.3758
# Epoch 26/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.3716 - val_loss: 1.3595
# Epoch 27/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.3411 - val_loss: 1.3036
# Epoch 28/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.3053 - val_loss: 1.2755
# Epoch 29/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.2727 - val_loss: 1.2534
# Epoch 30/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.2413 - val_loss: 1.2081
# Epoch 31/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.2043 - val_loss: 1.1689
# Epoch 32/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.1678 - val_loss: 1.1432
# Epoch 33/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.1485 - val_loss: 1.1145
# Epoch 34/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.1130 - val_loss: 1.0879
# Epoch 35/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.0883 - val_loss: 1.0625
# Epoch 36/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.0582 - val_loss: 1.0466
# Epoch 37/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.0247 - val_loss: 0.9975
# Epoch 38/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 1.0039 - val_loss: 0.9721
# Epoch 39/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.9723 - val_loss: 0.9660
# Epoch 40/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.9500 - val_loss: 0.9258
# Epoch 41/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.9244 - val_loss: 0.8970
# Epoch 42/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.9006 - val_loss: 0.8753
# Epoch 43/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.8772 - val_loss: 0.8547
# Epoch 44/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.8579 - val_loss: 0.8794
# Epoch 45/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.8371 - val_loss: 0.8203
# Epoch 46/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.8122 - val_loss: 0.7911
# Epoch 47/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.7933 - val_loss: 0.7720
# Epoch 48/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.7748 - val_loss: 0.7557
# Epoch 49/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.7597 - val_loss: 0.7380
# Epoch 50/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.7399 - val_loss: 0.7222
# Epoch 51/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.7222 - val_loss: 0.7017
# Epoch 52/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.7034 - val_loss: 0.6824
# Epoch 53/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.6853 - val_loss: 0.6657
# Epoch 54/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.6690 - val_loss: 0.6566
# Epoch 55/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.6531 - val_loss: 0.6431
# Epoch 56/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.6388 - val_loss: 0.6244
# Epoch 57/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.6238 - val_loss: 0.6129
# Epoch 58/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.6098 - val_loss: 0.5995
# Epoch 59/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.5974 - val_loss: 0.5839
# Epoch 60/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.5836 - val_loss: 0.5675
# Epoch 61/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.5707 - val_loss: 0.5549
# Epoch 62/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.5618 - val_loss: 0.5526
# Epoch 63/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.5469 - val_loss: 0.5372
# Epoch 64/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.5342 - val_loss: 0.5232
# Epoch 65/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.5233 - val_loss: 0.5298
# Epoch 66/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.5135 - val_loss: 0.4958
# Epoch 67/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4991 - val_loss: 0.5032
# Epoch 68/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4894 - val_loss: 0.4759
# Epoch 69/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4812 - val_loss: 0.4717
# Epoch 70/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4708 - val_loss: 0.4611
# Epoch 71/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4620 - val_loss: 0.4565
# Epoch 72/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4542 - val_loss: 0.4451
# Epoch 73/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4473 - val_loss: 0.4378
# Epoch 74/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4391 - val_loss: 0.4297
# Epoch 75/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4312 - val_loss: 0.4267
# Epoch 76/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4257 - val_loss: 0.4175
# Epoch 77/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4179 - val_loss: 0.4125
# Epoch 78/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4124 - val_loss: 0.4032
# Epoch 79/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4052 - val_loss: 0.4028
# Epoch 80/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.4063 - val_loss: 0.4001
# Epoch 81/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3949 - val_loss: 0.3904
# Epoch 82/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3861 - val_loss: 0.3805
# Epoch 83/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3829 - val_loss: 0.3807
# Epoch 84/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3747 - val_loss: 0.3681
# Epoch 85/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3662 - val_loss: 0.3614
# Epoch 86/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3585 - val_loss: 0.3524
# Epoch 87/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3556 - val_loss: 0.3485
# Epoch 88/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3481 - val_loss: 0.3413
# Epoch 89/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3412 - val_loss: 0.3391
# Epoch 90/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3359 - val_loss: 0.3407
# Epoch 91/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3307 - val_loss: 0.3300
# Epoch 92/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3269 - val_loss: 0.3262
# Epoch 93/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3214 - val_loss: 0.3228
# Epoch 94/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3189 - val_loss: 0.3217
# Epoch 95/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3158 - val_loss: 0.3175
# Epoch 96/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3128 - val_loss: 0.3149
# Epoch 97/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3092 - val_loss: 0.3121
# Epoch 98/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3052 - val_loss: 0.3223
# Epoch 99/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3058 - val_loss: 0.3132
# Epoch 100/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.3021 - val_loss: 0.3159
# Epoch 101/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2990 - val_loss: 0.3069
# Epoch 102/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2946 - val_loss: 0.3084
# Epoch 103/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2942 - val_loss: 0.3012
# Epoch 104/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2917 - val_loss: 0.2948
# Epoch 105/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2901 - val_loss: 0.2968
# Epoch 106/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2897 - val_loss: 0.2941
# Epoch 107/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2863 - val_loss: 0.2974
# Epoch 108/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2850 - val_loss: 0.2906
# Epoch 109/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2857 - val_loss: 0.2894
# Epoch 110/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2822 - val_loss: 0.2951
# Epoch 111/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2818 - val_loss: 0.2912
# Epoch 112/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2816 - val_loss: 0.2956
# Epoch 113/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2798 - val_loss: 0.2854
# Epoch 114/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2780 - val_loss: 0.2852
# Epoch 115/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2766 - val_loss: 0.2798
# Epoch 116/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2755 - val_loss: 0.2798
# Epoch 117/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2742 - val_loss: 0.2820
# Epoch 118/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2748 - val_loss: 0.2801
# Epoch 119/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2732 - val_loss: 0.2829
# Epoch 120/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2739 - val_loss: 0.2778
# Epoch 121/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2721 - val_loss: 0.2827
# Epoch 122/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2703 - val_loss: 0.2760
# Epoch 123/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2689 - val_loss: 0.2870
# Epoch 124/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2740 - val_loss: 0.2793
# Epoch 125/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2710 - val_loss: 0.2937
# Epoch 126/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2692 - val_loss: 0.2742
# Epoch 127/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2661 - val_loss: 0.2702
# Epoch 128/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2663 - val_loss: 0.2712
# Epoch 129/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2676 - val_loss: 0.2673
# Epoch 130/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2633 - val_loss: 0.2675
# Epoch 131/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2672 - val_loss: 0.2726
# Epoch 132/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2647 - val_loss: 0.2709
# Epoch 133/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2697 - val_loss: 0.2745
# Epoch 134/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2667 - val_loss: 0.2681
# Epoch 135/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2663 - val_loss: 0.2699
# Epoch 136/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2609 - val_loss: 0.2615
# Epoch 137/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2647 - val_loss: 0.2656
# Epoch 138/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2625 - val_loss: 0.2710
# Epoch 139/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2662 - val_loss: 0.2724
# Epoch 140/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2622 - val_loss: 0.2633
# Epoch 141/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2635 - val_loss: 0.2624
# Epoch 142/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2629 - val_loss: 0.2594
# Epoch 143/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2612 - val_loss: 0.2678
# Epoch 144/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2654 - val_loss: 0.2592
# Epoch 145/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2596 - val_loss: 0.2602
# Epoch 146/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2660 - val_loss: 0.2709
# Epoch 147/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2624 - val_loss: 0.2586
# Epoch 148/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2637 - val_loss: 0.2656
# Epoch 149/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2612 - val_loss: 0.2677
# Epoch 150/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2612 - val_loss: 0.2621
# Epoch 151/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2605 - val_loss: 0.2578
# Epoch 152/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2604 - val_loss: 0.2547
# Epoch 153/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2602 - val_loss: 0.2753
# Epoch 154/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2580 - val_loss: 0.2561
# Epoch 155/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2609 - val_loss: 0.2618
# Epoch 156/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2579 - val_loss: 0.2579
# Epoch 157/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2597 - val_loss: 0.2594
# Epoch 158/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2577 - val_loss: 0.2507
# Epoch 159/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2705 - val_loss: 0.2704
# Epoch 160/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2562 - val_loss: 0.2511
# Epoch 161/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2556 - val_loss: 0.2493
# Epoch 162/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2540 - val_loss: 0.2582
# Epoch 163/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2655 - val_loss: 0.2647
# Epoch 164/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2557 - val_loss: 0.2578
# Epoch 165/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2626 - val_loss: 0.2520
# Epoch 166/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2560 - val_loss: 0.2547
# Epoch 167/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2584 - val_loss: 0.2543
# Epoch 168/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2674 - val_loss: 0.2593
# Epoch 169/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2622 - val_loss: 0.2478
# Epoch 170/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2556 - val_loss: 0.2461
# Epoch 171/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2582 - val_loss: 0.2468
# Epoch 172/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2546 - val_loss: 0.2457
# Epoch 173/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2567 - val_loss: 0.2478
# Epoch 174/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2544 - val_loss: 0.2487
# Epoch 175/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2527 - val_loss: 0.2609
# Epoch 176/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2579 - val_loss: 0.2451
# Epoch 177/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2579 - val_loss: 0.2487
# Epoch 178/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2531 - val_loss: 0.2446
# Epoch 179/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2521 - val_loss: 0.2450
# Epoch 180/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2512 - val_loss: 0.2487
# Epoch 181/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2582 - val_loss: 0.2423
# Epoch 182/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2523 - val_loss: 0.2578
# Epoch 183/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2527 - val_loss: 0.2447
# Epoch 184/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2572 - val_loss: 0.2498
# Epoch 185/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2566 - val_loss: 0.2459
# Epoch 186/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2554 - val_loss: 0.2544
# Epoch 187/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2551 - val_loss: 0.2468
# Epoch 188/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2535 - val_loss: 0.2656
# Epoch 189/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2555 - val_loss: 0.2429
# Epoch 190/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2512 - val_loss: 0.2428
# Epoch 191/1000
# 53/53 [==============================] - 0s 6ms/step - loss: 0.2554 - val_loss: 0.2444
# Restoring model weights from the end of the best epoch.
# Epoch 00191: early stopping

# %%
metrics.r2_score(binned_data[['x']], binned_data[['x_pred_nn']])
# Out:
# 0.5789298441141236

# %%
# Split the data into trials
# state: [start_trial, movement, reward, failure, between_trials]
state = load_stream(r, 'state', stream_spec=stream_spec)
state.sort_values('sync', inplace=True)
# Assign trial numbers
state['trial_id'] = None  # make a new column

# number the 'start_trial' tokens
mask = state['state'] == 'start_trial'
state.loc[mask, 'trial_id'] = np.arange(len(state[mask]))

# assign the 'start_trial' number to tokens that come after it
current_trial = None
trial_ids = np.empty_like(state['trial_id'])
for i in range(state.shape[0]):
    if state['trial_id'].iloc[i] is not None:
        current_trial = state['trial_id'].iloc[i]
    trial_ids[i] = current_trial
state['trial_id'] = trial_ids

trials = state.pivot(index='trial_id', columns='state', values='sync')
trials.sort_index(axis=1, inplace=True)  # sort columns after pivoting
# drop failed trials and the between-trial period
trials.drop(['between_trials', 'failure'], axis=1, inplace=True)
trials.dropna(axis=0, inplace=True)  # drop incomplete trials
trials = trials / 30  # convert to milliseconds
for field in trials.columns:
    trials[field] = pd.to_timedelta(trials[field], unit='ms')

trial_dfs = []
align_field = 'movement'
start_offset, end_offset = pd.to_timedelta((-500, 1000), unit='ms')
bin_width = pd.to_timedelta(bin_size_ms, unit='ms')
for tid in trials.index.values:
    center = trials[align_field].loc[tid]
    a = center + start_offset
    b = center + end_offset
    trial_df = binned_data.loc[a:b].copy()
    trial_df['trial_id'] = tid
    trial_df['align_time'] = trial_df.index.ceil(bin_width) - center.ceil(
        bin_width)
    trial_dfs.append(trial_df)

# Combine all trials into one DataFrame
trial_data = pd.concat(trial_dfs, ignore_index=True)
aligned_trials = trial_data.pivot_table(index='align_time', columns='trial_id')

# %%
# plot predictions
trial_ids = trial_data['trial_id'].unique()[:10]

fig, axes = plt.subplots(ncols=2,
                         nrows=len(trial_ids),
                         figsize=(8, 2 * len(trial_ids)))

for i, trial_id in enumerate(trial_ids):
    t = aligned_trials.index.total_seconds()
    axes[i, 0].plot(t, aligned_trials['x'][trial_id], label='true')
    axes[i, 0].plot(t,
                    aligned_trials['x_pred_lm'][trial_id],
                    label='linear model',
                    alpha=0.7)
    axes[i, 0].plot(t,
                    aligned_trials['x_pred_nn'][trial_id],
                    label='FFN',
                    alpha=0.7)
    axes[i, 0].set_xlabel(f'Time from \n{align_field} (s)')
    axes[i, 0].set_ylabel(f'Trial {trial_id}')
    axes[i, 1].plot(t, aligned_trials['y'][trial_id], label='true')
    axes[i, 1].plot(t,
                    aligned_trials['y_pred_lm'][trial_id],
                    label='linear model',
                    alpha=0.7)
    axes[i, 1].plot(t,
                    aligned_trials['y_pred_nn'][trial_id],
                    label='FFN',
                    alpha=0.7)
    axes[i, 1].set_xlabel(f'Time from \n{align_field} (s)')
axes[0, 0].set_title('x')
axes[0, 1].set_title('y')
axes[0, -1].legend()

plt.tight_layout()
plt.savefig('force_predictions.pdf')
